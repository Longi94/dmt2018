# %%
import pandas as pd

# %%
dataset = pd.read_csv('ODI-2018.csv')

# %%
dataset
# Out:
#             Timestamp                                            prog   ml  \
# 0                 NaN                                             NaN  NaN
# 1    04/05/2018 11:22         Duisenberg Quantitative Risk Management   no
# 2    04/05/2018 11:23                                Computer Science   no
# 3    04/05/2018 11:23                              Business Analytics  yes
# 4    04/05/2018 11:23                                              BA  yes
# 5    04/05/2018 11:23   Master Computer Science: Big Data Engineering   no
# 6    04/05/2018 11:24                       Drug discovery and safety   no
# 7    04/05/2018 11:25                                              CS  yes
# 8    04/05/2018 11:25                           Computational Science   no
# 9    04/05/2018 11:25                         M Financial Economtrics   no
# 10   04/05/2018 11:25          MSc Bioinformatics and Systems Biology  yes
# ...

# %%
data['rand']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a603a515971a> in <module>()
# ----> 1 data['rand']
#
# NameError: name 'data' is not defined

# %%
data.dropna(subset=['rand'])
# Out:
#             Timestamp                                            prog  \
# 1    04/05/2018 11:22         Duisenberg Quantitative Risk Management
# 2    04/05/2018 11:23                                Computer Science
# 3    04/05/2018 11:23                              Business Analytics
# 4    04/05/2018 11:23                                              BA
# 5    04/05/2018 11:23   Master Computer Science: Big Data Engineering
# 6    04/05/2018 11:24                       Drug discovery and safety
# 7    04/05/2018 11:25                                              CS
# 8    04/05/2018 11:25                           Computational Science
# 9    04/05/2018 11:25                         M Financial Economtrics
# 10   04/05/2018 11:25          MSc Bioinformatics and Systems Biology
# 11   04/05/2018 11:25                                    Econometrics
# 12   04/05/2018 11:26                                              CS
# ...

# %%
data['rand'].dropna()
# Out:
# 1                7
# 2           394749
# 3                6
# 4                8
# 5                8
# 6               No
# 7             6739
# 8                3
# 9         78952097
# 10               5
# 11               8
# 12              42
# 13              37
# 14         7727528
# 15             187
# 16               7
# 17               7
# 18               6
# 19              34
# 20               7
# 21     6.28395E+36
# 22               2
# 23               2
# 24               6
# 25               7
# 26               4
# 27             Hoi
# 28               9
# 29               4
# 30               3
#           ...
# 188              3
# 189              4
# 190              9
# 191             10
# 192              1
# 193              9
# 194              2
# 195             42
# 196             69
# 197              9
# 198              8
# 199              7
# 200              3
# 201           ACHT
# 202              4
# 203         382763
# ...

# %%
pd.to_numeric(data['rand'], errors='drop')
data['rand'].dropna()
# Out:
# 1                7
# 2           394749
# 3                6
# 4                8
# 5                8
# 6               No
# 7             6739
# 8                3
# 9         78952097
# 10               5
# 11               8
# 12              42
# 13              37
# 14         7727528
# 15             187
# 16               7
# 17               7
# 18               6
# 19              34
# 20               7
# 21     6.28395E+36
# 22               2
# 23               2
# 24               6
# 25               7
# 26               4
# 27             Hoi
# 28               9
# 29               4
# 30               3
#           ...
# 188              3
# 189              4
# 190              9
# 191             10
# 192              1
# 193              9
# 194              2
# 195             42
# 196             69
# 197              9
# 198              8
# 199              7
# 200              3
# 201           ACHT
# 202              4
# 203         382763
# ...

# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install seaborn

import seaborn as sns

# %%
sns.distplot(data['rand']);

# %%
dataset.cov()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
