# %%
import pandas as pd

# %%
data = pd.read_csv('training_set_VU_DM_2014.csv')
data.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score      ...       comp6_rate_percent_diff  \
# 0                3                3.5      ...                           NaN
# 1                4                4.0      ...                           NaN
# 2                3                4.5      ...                           NaN
# 3                2                4.0      ...                           NaN
# 4                4                3.5      ...                           NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff  click_bool  gross_bookings_usd  booking_bool
# 0                      NaN           0                 NaN             0
# 1                      NaN           0                 NaN             0
# 2                      NaN           0                 NaN             0
# 3                      5.0           0                 NaN             0
# 4                      NaN           0                 NaN             0
#
# [5 rows x 54 columns]

# %%
sampled = data.groupby(by='srch_id', as_index=False)
sampled.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32fb969beae1> in <module>()
# ----> 1 sampled = data.groupby(by='srch_id', as_index=False)
#       2 sampled.head()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data = pd.read_csv('training_set_VU_DM_2014.csv')
#data.head()
sampled = data.groupby(by='srch_id', as_index=False)
#sampled.head()

# %%
selected_names = np.random.choice(data.srch_id.unique(),5000,replace = False)
grouped = data[data.srch_id.isin(selected_names)]
#grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4e44dfc7b9d7> in <module>()
# ----> 1 selected_names = np.random.choice(data.srch_id.unique(),5000,replace = False)
#       2 grouped = data[data.srch_id.isin(selected_names)]
#       3 #grouped.head()
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
selected_names = np.random.choice(data.srch_id.unique(),5000,replace = False)
grouped = data[data.srch_id.isin(selected_names)]
#grouped.head()

# %%
grouped.to_csv('5000users')
data = pd.read_csv('5000users')
data.head()
# Out:
#    Unnamed: 0  srch_id            date_time  site_id  \
# 0          28        4  2012-12-31 08:59:22        5
# 1          29        4  2012-12-31 08:59:22        5
# 2          30        4  2012-12-31 08:59:22        5
# 3          31        4  2012-12-31 08:59:22        5
# 4          32        4  2012-12-31 08:59:22        5
#
#    visitor_location_country_id  visitor_hist_starrating  visitor_hist_adr_usd  \
# 0                          219                      NaN                   NaN
# 1                          219                      NaN                   NaN
# 2                          219                      NaN                   NaN
# 3                          219                      NaN                   NaN
# 4                          219                      NaN                   NaN
#
#    prop_country_id  prop_id  prop_starrating      ...       \
# 0              219     3625                4      ...
# 1              219    11622                4      ...
# 2              219    11826                5      ...
# 3              219    22824                3      ...
# 4              219    37581                5      ...
#
#    comp6_rate_percent_diff  comp7_rate  comp7_inv  comp7_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp8_rate  comp8_inv  comp8_rate_percent_diff  click_bool  \
# 0         NaN        NaN                      NaN           0
# 1         NaN        NaN                      NaN           0
# 2         NaN        NaN                      NaN           0
# 3         NaN        NaN                      NaN           0
# 4         NaN        NaN                      NaN           0
#
#    gross_bookings_usd  booking_bool
# 0                 NaN             0
# 1                 NaN             0
# 2                 NaN             0
# 3                 NaN             0
# 4                 NaN             0
#
# [5 rows x 55 columns]

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %%
posdata = data.groupby('position')

# %%
labels = range(1, 40)

# %%
sns.distplot(posdata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1201         try:
# -> 1202             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1203         except TypeError:
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#      77                          default_axis=default_axis),
# ---> 78         radd=arith_method(lambda x, y: y + x, names('radd'), op('+'),
#      79                           default_axis=default_axis),
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1376             with np.errstate(all='ignore'):
# -> 1377                 result = get_result(other)
#    1378
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get_result(other)
#    1345             else:
# -> 1346                 result = func(values, other)
#    1347
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1227                     with np.errstate(all='ignore'):
# -> 1228                         result[mask] = op(xrav, y)
#    1229             else:
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#      77                          default_axis=default_axis),
# ---> 78         radd=arith_method(lambda x, y: y + x, names('radd'), op('+'),
#      79                           default_axis=default_axis),
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-1ac9b3ebede8> in <module>()
# ----> 1 sns.distplot(posdata)
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     190             line, = ax.plot(0, a.mean())
#     191         else:
# --> 192             line, = ax.plot(a.mean(), 0)
#     193         color = line.get_color()
#     194         line.remove()
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1265                 self = self.fillna(fill_value)
#    1266
# -> 1267             return self._combine_const(other, na_op)
#    1268
#    1269     f.__name__ = name
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _combine_const(self, other, func, errors, try_cast)
#    3985         new_data = self._data.eval(func=func, other=other,
#    3986                                    errors=errors,
# -> 3987                                    try_cast=try_cast)
#    3988         return self._constructor(new_data)
#    3989
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    3433
#    3434     def eval(self, **kwargs):
# -> 3435         return self.apply('eval', **kwargs)
#    3436
#    3437     def quantile(self, **kwargs):
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1382             raise
#    1383         except Exception as detail:
# -> 1384             result = handle_error()
#    1385
#    1386         # technically a broadcast error in numpy can 'work' by returning a
#
# /Users/Morsal/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in handle_error()
#    1365                 # The 'detail' variable is defined in outer scope.
#    1366                 raise TypeError('Could not operate %s with block values %s' %
# -> 1367                                 (repr(other), str(detail)))  # noqa
#    1368             else:
#    1369                 # return the values
#
# TypeError: Could not operate 1 with block values unsupported operand type(s) for +: 'int' and 'str'

# %%
w
